# %%
import pandas as pd

# %%
df = pd.read_csv('country_wise_latest.csv')

# %%
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
## Top data in this case 20

df.head(20)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# 5   Antigua and Barbuda         86       3         65      18          4
# 6             Argentina     167416    3059      72575   91782       4890
# 7               Armenia      37390     711      26665   10014         73
# 8             Australia      15303     167       9311    5825        368
# 9               Austria      20558     713      18246    1599         86
# 10           Azerbaijan      30446     423      23242    6781        396
# 11              Bahamas        382      11         91     280         40
# ...

# %%
## Remove a Whole Column Data 

df.drop(['Confirmed'], axis = 1 , inplace=True) # inplace variable do the changes in the whole df function so that is call'd again will display the changed

# %%
df.rename(columns={'Country/Region':'Countries'}, inplace=True)

# %%
df.describe()
# Out:
# c:\Users\kesha\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#               Deaths     Recovered        Active     New cases   New deaths  \
# count     187.000000  1.870000e+02  1.870000e+02    187.000000   187.000000
# mean     3497.518717  5.063148e+04  3.400194e+04   1222.957219    28.957219
# std     14100.002482  1.901882e+05  2.133262e+05   5710.374790   120.037173
# min         0.000000  0.000000e+00  0.000000e+00      0.000000     0.000000
# 25%        18.500000  6.265000e+02  1.415000e+02      4.000000     0.000000
# 50%       108.000000  2.815000e+03  1.600000e+03     49.000000     1.000000
# 75%       734.000000  2.260600e+04  9.149000e+03    419.500000     6.000000
# max    148011.000000  1.846641e+06  2.816444e+06  56336.000000  1076.000000
#
#        New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Countries               187 non-null    object
#  1   Deaths                  187 non-null    int64
#  2   Recovered               187 non-null    int64
#  3   Active                  187 non-null    int64
#  4   New cases               187 non-null    int64
#  5   New deaths              187 non-null    int64
#  6   New recovered           187 non-null    int64
#  7   Deaths / 100 Cases      187 non-null    float64
#  8   Recovered / 100 Cases   187 non-null    float64
#  9   Deaths / 100 Recovered  187 non-null    float64
#  10  Confirmed last week     187 non-null    int64
#  11  1 week change           187 non-null    int64
#  12  1 week % increase       187 non-null    float64
#  13  WHO Region              187 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Countries', 'Deaths', 'Recovered', 'Active', 'New cases', 'New deaths',
#        'New recovered', 'Deaths / 100 Cases', 'Recovered / 100 Cases',
#        'Deaths / 100 Recovered', 'Confirmed last week', '1 week change',
#        '1 week % increase', 'WHO Region'],
#       dtype='object')

# %%
df
# Out:
#               Countries  Deaths  Recovered  Active  New cases  New deaths  \
# 0           Afghanistan    1269      25198    9796        106          10
# 1               Albania     144       2745    1991        117           6
# 2               Algeria    1163      18837    7973        616           8
# 3               Andorra      52        803      52         10           0
# 4                Angola      41        242     667         18           1
# ..                  ...     ...        ...     ...        ...         ...
# 182  West Bank and Gaza      78       3752    6791        152           2
# 183      Western Sahara       1          8       1          0           0
# 184               Yemen     483        833     375         10           4
# 185              Zambia     140       2815    1597         71           1
# 186            Zimbabwe      36        542    2126        192           2
#
#      New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.fillna('NA')
# Out:
#               Countries  Deaths  Recovered  Active  New cases  New deaths  \
# 0           Afghanistan    1269      25198    9796        106          10
# 1               Albania     144       2745    1991        117           6
# 2               Algeria    1163      18837    7973        616           8
# 3               Andorra      52        803      52         10           0
# 4                Angola      41        242     667         18           1
# ..                  ...     ...        ...     ...        ...         ...
# 182  West Bank and Gaza      78       3752    6791        152           2
# 183      Western Sahara       1          8       1          0           0
# 184               Yemen     483        833     375         10           4
# 185              Zambia     140       2815    1597         71           1
# 186            Zimbabwe      36        542    2126        192           2
#
#      New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Countries               187 non-null    object
#  1   Deaths                  187 non-null    int64
#  2   Recovered               187 non-null    int64
#  3   Active                  187 non-null    int64
#  4   New cases               187 non-null    int64
#  5   New deaths              187 non-null    int64
#  6   New recovered           187 non-null    int64
#  7   Deaths / 100 Cases      187 non-null    float64
#  8   Recovered / 100 Cases   187 non-null    float64
#  9   Deaths / 100 Recovered  187 non-null    float64
#  10  Confirmed last week     187 non-null    int64
#  11  1 week change           187 non-null    int64
#  12  1 week % increase       187 non-null    float64
#  13  WHO Region              187 non-null    object
# ...

# %%
df2 = df.groupby('Countries')[['Deaths','Recovered','Active']].sum().reset_index()

# %%
df2
# Out:
#               Countries  Deaths  Recovered  Active
# 0           Afghanistan    1269      25198    9796
# 1               Albania     144       2745    1991
# 2               Algeria    1163      18837    7973
# 3               Andorra      52        803      52
# 4                Angola      41        242     667
# ..                  ...     ...        ...     ...
# 182  West Bank and Gaza      78       3752    6791
# 183      Western Sahara       1          8       1
# 184               Yemen     483        833     375
# 185              Zambia     140       2815    1597
# 186            Zimbabwe      36        542    2126
#
# [187 rows x 4 columns]

# %%
df[df['Countries'] =='India']
# Out:
#    Countries  Deaths  Recovered  Active  New cases  New deaths  New recovered  \
# 79     India   33408     951166  495499      44457         637          33598
#
#     Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  \
# 79                2.26                  64.26                    3.51
#
#     Confirmed last week  1 week change  1 week % increase       WHO Region
# 79              1155338         324735              28.11  South-East Asia
